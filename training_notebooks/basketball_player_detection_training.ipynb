# %% [markdown]
# # Install Libraries

# %%
# Installs the official Ultralytics package, which provides access to YOLO (You Only Look Once) models
# !pip install ultralytics
# Installs the Roboflow SDK, which lets you connect to your Roboflow account to programmatically download dataset versions, apply augmentations, manage computer vision annotations, and upload models directly from code.
# !pip install roboflow
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from roboflow import Roboflow

# Initialize the Roboflow client using your private API key for authentication
rf = Roboflow(api_key="CyHStWaMAHu3qgwEsHXO")

# Access the target project within the specified workspace
project = rf.workspace("workspace-5ujvu").project("basketball-players-fy4c2-vfsuv")

# Select dataset Version 3 from the project history
version = project.version(3)

# Download the dataset locally, structured specifically for YOLOv8 (includes image folders and data.yaml)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 plots=True batch=8
# Out:
# New https://pypi.org/project/ultralytics/8.4.115 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.67 🚀 Python-3.11.0 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# ...
